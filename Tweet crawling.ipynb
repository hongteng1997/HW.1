# %%
#API KEY: ESokuvqivbjkdDsByNFQZf8mN
#API key Secret: Jy6MTfHeJpD8e2CV7su8MimnNzoxa26cP2xOJRUzG3tZ0gxiRt
#Access Token: 1454940276120772616-Tc863M7rjLwjzX8rySjFb9RtTm4eXf
#Access Token Secret:MEUENBIlocOWpwPEGWNlrbJnuW44TApmpfKK903NcIops

# %%
# !pip3 install tweepy

# %%
import os
import tweepy
import pandas as pd
import csv

# %%
auth = tweepy.auth.OAuthHandler('ESokuvqivbjkdDsByNFQZf8mN', 'Jy6MTfHeJpD8e2CV7su8MimnNzoxa26cP2xOJRUzG3tZ0gxiRt')
auth.set_access_token('1454940276120772616-Tc863M7rjLwjzX8rySjFb9RtTm4eXf', 'MEUENBIlocOWpwPEGWNlrbJnuW44TApmpfKK903NcIops')
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
search_words=["ATT", "ATT 5G","ATT Price","ATT phone"]
for key in search_words:
    new_search=(key)+"-filter:retweets"
num_of_tweets = 100

tweets = tweepy.Cursor(api.search_tweets,
                       q=new_search,
                       lang="en").items(num_of_tweets)

tweet_text = [tweet.text.encode('utf-8') for tweet in tweets]
tweet_text
# Out:
# [b"@ATT got a new phone two months ago and I am a new  Customer Still haven't got my phone ported right so I can't get\xe2\x80\xa6 https://t.co/So6wkSicy3",
#  b'.@ATT crews continue repairing a fiber line that was cut in #Chualar. This caused cell phone, landline phone and in\xe2\x80\xa6 https://t.co/Nth994aLGa',
#  b'"Consider uploading your own first party Custom Audience lists using hashed email and/or hashed phone if allowed by\xe2\x80\xa6 https://t.co/3g7SjZ1h0i',
#  b'@burd06jaimee @ATT Cancel the new installment plans, so it shows I owe $900 on a phone that I don\xe2\x80\x99t even have lol m\xe2\x80\xa6 https://t.co/gVfr7kt8DT',
#  b'@burd06jaimee @ATT I was going from the XR to the reg 13 in pink as well. The back order date was between November\xe2\x80\xa6 https://t.co/XUmeFcA9wM',
#  b'@JoseGNoel @ATT @ATTHelp My cell phone has been tripping all day.',
# ...

# %%
tweets = tweepy.Cursor(api.search_tweets,
              q=new_search,
              lang="en").items(num_of_tweets)


tweets_info = [[tweet.id,
               tweet.user.screen_name, 
                tweet.user.followers_count, 
                tweet.user.location, 
                tweet.text.encode('utf-8')] for tweet in tweets]


tweet_info = pd.DataFrame(data=tweets_info, 
                    columns=["Tweet ID","Screen Name", "Number of Followers", "Location", "Tweet"])


tweet_info
# Out:
#                Tweet ID     Screen Name  Number of Followers  \
# 0   1455384808175988737     ArtMProctor                    9
# 1   1455370985595490304  davidaguilar92                  807
# 2   1455364374445494279        kyotonio                  575
# 3   1455363435265511427     AngieBerens                  460
# 4   1455363234014408710     AngieBerens                  460
# ..                  ...             ...                  ...
# 95  1455161779399573506       Zigaflint                  119
# 96  1455159950385287168     ryanatanner                  271
# 97  1455159065055744000       Chenagrrl                 1380
# 98  1455157697423282188    T_Shirt_Lady                  269
# 99  1455157417436712960      rcknrllmom                15932
#
#                   Location                                              Tweet
# 0    On my way to the moon  b"@ATT got a new phone two months ago and I am...
# ...

# %%
tweet_info.to_csv(str(search_words)+"_tweets.csv",index=False)

# %%
search_words=["Tmobile", "Tmobile 5G","Tmobile Price","Tmobile phone"]
for key in search_words:
    new_search=(key)+"-filter:retweets"

num_of_tweets = 100

tweets = tweepy.Cursor(api.search_tweets,
                       q=new_search,
                       lang="en").items(num_of_tweets)

tweet_text = [tweet.text.encode('utf-8') for tweet in tweets]
tweet_text
# Out:
# [b'My iPhone is paid in full now. I wanna unlock my phone @TMobileHelp @TMobile',
#  b'I be ready to let TMobile cut my phone off permanently and go back to writing letters',
#  b'@pjs0210 @debcombs14 TMobile has a super cheap, truly unlimited senior plan. I think age 55. I live in Washington,\xe2\x80\xa6 https://t.co/tlCCUSJlPK',
#  b"@BrentIrwin3 @ShieldVoC @TMobile @TMobileHelp Yes I do have coverage. I also ways get coverage, however that doesn'\xe2\x80\xa6 https://t.co/9jKkveXfsZ",
#  b"@TMobile @Asurion @Asurion @AsurionCaresHere @TMobile\n @Sprint and all of this and I still haven't gotten my phone\xe2\x80\xa6 https://t.co/AD0WArKrWw",
#  b'@TMobile @Sprint @Asurion @AsurionCaresHere so finally one of the more sorrier @TMobile @Sprint employees because t\xe2\x80\xa6 https://t.co/omcIHhMZ6m',
#  b'1) @TMobile @Sprint @Asurion @AsurionCaresHere is what I am going to do, I am going to buy a 30 day ad Instagram an\xe2\x80\xa6 https://t.co/EqnFd5689x',
# ...

# %%
tweets = tweepy.Cursor(api.search_tweets,
              q=new_search,
              lang="en").items(num_of_tweets)


tweets_info = [[tweet.id,
               tweet.user.screen_name, 
                tweet.user.followers_count, 
                tweet.user.location, 
                tweet.text.encode('utf-8')] for tweet in tweets]


tweet_info = pd.DataFrame(data=tweets_info, 
                    columns=["Tweet ID","Screen Name", "Number of Followers", "Location", "Tweet"])


tweet_info
# Out:
#                Tweet ID      Screen Name  Number of Followers  \
# 0   1455397092843823104         chulinli                   23
# 1   1455384232327450626        anaparraj                  276
# 2   1455384036411510786          OnHonor                  205
# 3   1455381597109334023       ramon_djon                  221
# 4   1455381292137254913  DexterousPorter                   36
# ..                  ...              ...                  ...
# 95  1455048042839642117       pokebrain1                  189
# 96  1455045669811474436       spy_apps45                  370
# 97  1455005821377581062   onthelookout41                 2247
# 98  1455004294961254400       Nancyburr9                    0
# 99  1454977260671229960       DoggoKelso                    6
#
#                          Location  \
# 0
# 1
# 2                 Washington, USA
# 3   Wouldn't You like to know....
# 4                             USA
# ..                            ...
# 95
# 96
# ...

# %%
tweet_info.to_csv(str(search_words)+"_tweets.csv",index=False)

# %%
search_words=["Verizon", "Verizon 5G","Verizon Price","Verizon phone"]
for key in search_words:
    new_search=(key)+"-filter:retweets"
num_of_tweets = 100

tweets = tweepy.Cursor(api.search_tweets,
                       q=new_search,
                       lang="en").items(num_of_tweets)

tweet_text = [tweet.text.encode('utf-8') for tweet in tweets]
tweet_text
# Out:
# [b"@madebygoogle I'm an anxiously awaiting delivery of my Pixel 6 Pro. The delivery from @Verizon is in December. The\xe2\x80\xa6 https://t.co/O2KXKGwfk5",
#  b'Unlock Verizon iPhone 13 here:  https://t.co/Ki8vJCi8EQ https://t.co/3T5hgWMYKO',
#  b'@vzpublicsector @Verizon Has there been an outtage? My phone says no service, I\xe2\x80\x99m in NYC',
#  b"To Verizon's credit, the rep did check stores and predictably had none available but hey, A for effort\n\nI think I g\xe2\x80\xa6 https://t.co/S9fBGWGfmH",
#  b'@MorganGuyton5 Save me a lot of phone calls I should t make an money for this Verizon plan\xf0\x9f\x98\x82',
#  b'Our undercover shoppers checked pricing from AT&amp;T, T-Mobile, Verizon, and more than a dozen lesser-known carriers,\xe2\x80\xa6 https://t.co/SLDCQMwiij',
#  b'Cable phone numbers are used they see the time machine in Astoria air station hanging out in apple satellites means\xe2\x80\xa6 https://t.co/1oQwOTObSY',
# ...

# %%
tweets = tweepy.Cursor(api.search_tweets,
              q=new_search,
              lang="en").items(num_of_tweets)


tweets_info = [[tweet.id,
               tweet.user.screen_name, 
                tweet.user.followers_count, 
                tweet.user.location, 
                tweet.text.encode('utf-8')] for tweet in tweets]


tweet_info = pd.DataFrame(data=tweets_info, 
                    columns=["Tweet ID","Screen Name", "Number of Followers", "Location", "Tweet"])


tweet_info
# Out:
#                Tweet ID      Screen Name  Number of Followers  \
# 0   1455397285513342978   Dangeresque762                  562
# 1   1455393872582828035  CanadaUnlocking                 3901
# 2   1455388577114869761          mrtoval                  101
# 3   1455387417163100163           Arcon_                 1122
# 4   1455377413970477064       OleeNattyy                  776
# ..                  ...              ...                  ...
# 95  1455243918073860099       ChyClassyy                   79
# 96  1455242865941045260  christenpointer                  111
# 97  1455242163961352192  LiviaRo53525648                   49
# 98  1455235962779361288      krissyville                  434
# 99  1455235259243577347           rxmsxy                 5030
#
#                      Location  \
# 0          Flowery Branch, GA
# 1                      Canada
# 2   NYC is where i reside. 🇵🇪
# 3             Haunted Mansion
# 4                 Douglas, AL
# ..                        ...
# ...

# %%
tweet_info.to_csv(str(search_words)+"_tweets.csv",index=False)
